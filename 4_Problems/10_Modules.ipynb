# %%
import salary_calcultor
base_salary = salary_calcultor.calculate_salary(50, 40)
print(f"Base Salary: ${base_salary:.2f}")
# Out:
# Base Salary: $114400.00

# %%
import job_filter
job_postings = [
    {'title': 'Data Scientist', 'location': 'New York'},
    {'title': 'Data Analyst', 'location': 'San Francisco'},
    {'title': 'Machine Learning Engineer', 'location': 'New York'},
    {'title': 'Software Developer', 'location': 'Chicago'}
]
ny_jobs = job_filter.filter_jobs_by_location(job_postings, 'New York')

print("Jobs in New York:")

for job in ny_jobs:
    print(job['title'])
# Out:
# Jobs in New York:
# Data Scientist
# Machine Learning Engineer
