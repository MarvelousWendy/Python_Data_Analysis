# %% [markdown]
# <a href="https://colab.research.google.com/github/MarvelousAlex/Python_Data_Analysis/blob/main/05_Pandas_Index_Management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Index Management

# %% [markdown]
# load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## Index Attributes
#
# ### Notes
#
# * You can get or set properties of the index, such as its name or data type.
# * It's helpful for maintaining metadata or ensuring index compatibility in operations.
# * `(index.name, index.dtype)`
#     * `index.name` - name of the index
#     * `index.dtype` - data type of the index

# %% [markdown]
# Let's look at our DataFrame.

# %%
df.sample(3)
# Out:
#        job_title_short                                          job_title  \
# 16918     Data Analyst                             Master Data, Analyst I
# 396182  Data Scientist                               Reliability Engineer
# 3666    Data Scientist  Entry Level Data Scientist (Remote) - Full-tim...
#
#                              job_location             job_via  \
# 16918   Petaling Jaya, Selangor, Malaysia        via LinkedIn
# 396182                     Ghent, Belgium  via BeBee Belgique
# 3666                          Orlando, FL        via Snagajob
#
#        job_schedule_type  job_work_from_home         search_location  \
# 16918               None               False                Malaysia
# 396182         Full-time               False                 Belgium
# 3666           Full-time               False  Florida, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 16918  2023-06-14 13:16:21                   True                 False
# 396182 2023-03-05 18:10:45                  False                 False
# 3666   2023-03-02 13:07:25                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 16918        Malaysia        None              NaN              NaN
# 396182        Belgium        None              NaN              NaN
# 3666    United States        None              NaN              NaN
#
#           company_name                     job_skills  \
# 16918   Kimberly-Clark                           None
# 396182            VDAB                           None
# 3666     SynergisticIT  ['python', 'java', 'tableau']
#
#                                           job_type_skills
# 16918                                                None
# 396182                                               None
# 3666    {'analyst_tools': ['tableau'], 'programming': ...

# %% [markdown]
# Let's inspect our index.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Our index is a range of numbers, inspecting the name...

# %%
df.index.name

# %% [markdown]
# It has no name... so let's name it.

# %%
df.index.name = 'job_index'

# %% [markdown]
# Inspecting it.

# %%
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Out:
#                 job_title_short                            job_title  \
# job_index
# 635029     Senior Data Engineer                     Data Engineer Sr
# 369939        Software Engineer  Software Developer / Senior Analyst
# 662111            Data Engineer                    Big Data Engineer
#
#                            job_location           job_via job_schedule_type  \
# job_index
# 635029        Mexico City, CDMX, Mexico  via BeBee México         Full-time
# 369939                Santa Barbara, CA      via LinkedIn         Full-time
# 662111     Sant Cugat del Vallès, Spain      via LinkedIn         Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 635029                  False                     Mexico 2023-06-13 12:14:07
# 369939                  False  California, United States 2023-10-13 23:01:09
# 662111                  False                      Spain 2023-09-06 10:31:13
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 635029                      True                 False         Mexico
# 369939                     False                  True  United States
# 662111                     False                 False          Spain
#
#           salary_rate  salary_year_avg  salary_hour_avg      company_name  \
# job_index
# 635029           None              NaN              NaN            NEORIS
# 369939           year         107500.0              NaN     Direct Relief
# 662111           None              NaN              NaN  GFT Technologies
#
#                                                   job_skills  \
# job_index
# 635029     ['sql', 'python', 'r', 'java', 'rust', 'golang...
# 369939     ['sql', 'c#', 'python', 'sql server', 'qlik', ...
# 662111     ['scala', 'java', 'no-sql', 'mongodb', 'mongod...
#
#                                              job_type_skills
# job_index
# 635029     {'analyst_tools': ['sap', 'tableau'], 'cloud':...
# 369939     {'analyst_tools': ['qlik', 'sap', 'sharepoint'...
# 662111     {'cloud': ['databricks', 'gcp', 'azure', 'aws'...

# %% [markdown]
# ### Example 2
#
#  Remember the pivot table we made in the last example? Where we got median yearly salaries for the different job titles. Let's run that code. Then we'll get the index name and the data type of the index using `df.index.name` and `df.index.dtype`.

# %%
median_pivot = df.pivot_table(
    values='salary_year_avg',
    index='job_title_short',
    aggfunc='median'
)

median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
index_name = median_pivot.index.name
index_name
# Out:
# 'job_title_short'

# %%
index_dtype = median_pivot.index.dtype
index_dtype
# Out:
# dtype('O')

# %% [markdown]
# ## reset_index()
#
# ### Notes
#
# * `reset_index()`: Resets the DataFrame’s index to the default integer index. This is particularly useful after operations that alter the index, like sorting or filtering, to simplify further data manipulation.

# %% [markdown]
# ### Example 1
#
# When we create new DataFrames by filtering this jacks up our index!

# %%
df_usa = df[df.job_country == 'United States']

df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.index
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %% [markdown]
# Index is no longer correctly spaced by 1 increment.

# %%
df_usa.reset_index(inplace = True)
df_usa.head(10)
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
# 5         11         Data Engineer
# 6         13  Senior Data Engineer
# 7         17        Data Scientist
# 8         26         Data Engineer
# 9         27         Data Engineer
#
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2                                  GCP Data Engineer
# 3                  Senior Data Engineer  - GCP Cloud
# 4                                  Data Scientist II
# 5                                      Data Engineer
# 6                               Senior Data Engineer
# 7                             Data Science Team Lead
# 8                                      Data Engineer
# 9  Principal Data Engineer (Lead), Knowledge Grap...
#
#                          job_location  \
# 0                       Watertown, CT
# 1                     San Antonio, TX
# 2                            Anywhere
# 3                        Dearborn, MI
# 4                            Anywhere
# 5  Colorado Springs, CO   (+3 others)
# 6                        New York, NY
# 7                          Laurel, MD
# 8                       United States
# 9                   San Francisco, CA
#
#                                              job_via  \
# 0                                    via Work Nearby
# 1                                  via Diversity.com
# 2                                   via ZipRecruiter
# 3                                       via LinkedIn
# 4                                   via ZipRecruiter
# 5                                       via The Muse
# 6                                       via LinkedIn
# 7  via APL Careers - Johns Hopkins University App...
# 8                                       via LinkedIn
# 9                                       via LinkedIn
#
#           job_schedule_type  job_work_from_home          search_location  \
# 0                 Full-time               False     Texas, United States
# 1                 Full-time               False     Texas, United States
# 2  Contractor and Temp work                True                  Georgia
# 3                 Full-time               False   Florida, United States
# 4                 Full-time                True  New York, United States
# 5                 Full-time               False     Texas, United States
# 6                 Full-time               False     Texas, United States
# 7                 Full-time               False                  Georgia
# 8                 Full-time               False                  Georgia
# 9                 Full-time               False                  Georgia
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0 2023-06-16 13:44:15                  False                 False
# 1 2023-07-04 13:01:41                   True                 False
# 2 2023-11-07 14:01:59                  False                 False
# 3 2023-03-27 13:18:18                  False                 False
# 4 2023-04-23 13:02:57                  False                 False
# 5 2023-11-03 13:06:51                  False                  True
# 6 2023-11-15 13:08:52                   True                  True
# 7 2023-06-13 13:25:17                  False                  True
# 8 2023-09-15 13:56:18                   True                 False
# 9 2023-02-18 13:31:24                  False                 False
#
#      job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0  United States        None              NaN              NaN
# 1  United States        None              NaN              NaN
# 2  United States        None              NaN              NaN
# 3  United States        None              NaN              NaN
# 4  United States        None              NaN              NaN
# 5  United States        None              NaN              NaN
# 6  United States        None              NaN              NaN
# 7  United States        None              NaN              NaN
# 8  United States        None              NaN              NaN
# 9  United States        None              NaN              NaN
#
#                                company_name  \
# 0                      Boehringer Ingelheim
# 1              Southwest Research Institute
# 2                           smart folks inc
# 3             Miracle Software Systems, Inc
# 4                Radwell International, LLC
# 5                                   Philips
# 6                                     Nayya
# 7  Johns Hopkins Applied Physics Laboratory
# 8               Infinite Computer Solutions
# 9                                Altos Labs
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 5                                 ['python', 'qlik']
# 6  ['python', 'sql', 'go', 'ruby', 'ruby', 'javas...
# 7                             ['go', 'apl', 'excel']
# 8                                               None
# 9                            ['python', 'r', 'java']
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 5  {'analyst_tools': ['qlik'], 'programming': ['p...
# 6  {'cloud': ['aws'], 'other': ['terraform'], 'pr...
# 7  {'analyst_tools': ['excel'], 'programming': ['...
# 8                                               None
# 9           {'programming': ['python', 'r', 'java']}

# %% [markdown]
# Technically we could `.drop()` the `job_index`.
#
# BUT, if we wanted to do some sort of merge operations in the future with our original DataFrame, this provides the unique `id` to do that.

# %% [markdown]
# ### Example 2
#
# Back to our main DataFrame with our job postings in it. We're going to actually reset the indexes in the pivot table so `job_title_short` isn't the index anymore.

# %%
median_pivot.reset_index(inplace = True)

median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %% [markdown]
# ## set_index()
#
# ### Notes
#
# * `set_index()`: Sets one or more existing columns as the index of the DataFrame. This is useful for timeseries data or when you want to index by specific attributes.

# %% [markdown]
# ### Example 1
#
# What if we wanted to go back to job_index as our main index?

# %%
df_usa.set_index('job_index', inplace=True)

df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# ### Example 2
#
# Now that we've reset our index we can set the new index on another column like `salary_year_avg`.

# %%
median_pivot.set_index('job_title_short', inplace = True)

median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# ## sort_index()
#
# ### Notes
#
# * `sort_index()`: Sorts the DataFrame by the index (row labels), either ascending or descending. This helps in quickly organizing data by the index and is often used after `set_index()`.

# %% [markdown]
# ### Example
#
# Back to our pivoted DataFrame let's sort this new index alphabetically.

# %%
median_pivot.sort_index(inplace = True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0
