# %% [markdown]
# Exercise - Analyzing Data Science Job Demand

# %% [markdown]
# Topics Covered
#
# This exercise goes over:
#
# - Data cleaning and preparation
# - Data management
# - Extract from datetime
# - Pivot tables
# - Index management
#
# Question
#
# In our project we want to see how in-demand skills are trending for data jobs. But before we do that let's look at:
#
# - General trend of data jobs in demand. We're going to look at it by month.

# %% [markdown]
# Load data

# %%
# Importing libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading the dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# Demand of Data Jobs
#
# 1. First step is we're only going to look at roles in the United States. So we're going to create a copy of our DataFrame and only include roles that are in the United States.

# %%
# Skill count per month for data analyst roles
df_US = df[df['job_country'] == 'United States'].copy()

# %% [markdown]
# 2. Since we're getting the count by month we need to aggregate by month. We can do this by first extracting the month from our `job_posted_date` column.

# %%
# Extracting month name from job_posted_date
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')

# %% [markdown]
# 3. Next let's pivot by month and `job_title_short` and get the count.

# %%
df_US_pivot = df_US.pivot_table(
    index='job_posted_month',
    columns='job_title_short', aggfunc='size')

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# April                      2801            4867                         51
# August                     3269            6318                         68
# December                   2641            3472                        119
# February                   3060            4956                         56
# January                    2655            6915                         60
# July                       2570            4876                         65
# June                       2893            4645                         48
# March                      3183            4779                         59
# May                        2976            4377                         49
# November                   2793            4175                        132
# October                    3015            4882                        101
# September                  3224            4568                        113
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# April                            1025                   781
# August                           1186                   903
# December                          601                   689
# February                         1258                   878
# January                          1544                   773
# July                              883                   747
# June                             1009                   812
# March                            1114                   829
# May                               839                   746
# November                          656                   684
# October                           871                   672
# September                         805                   775
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# April                               991                112
# August                             1515                194
# December                            752                212
# February                           1127                 90
# January                            1552                114
# July                               1095                153
# June                               1033                 93
# March                              1150                115
# May                                 914                 90
# November                            816                194
# October                             987                219
# September                          1014                228

# %% [markdown]
# 4. Let's sort this.
#
# NOTE: See bottom of this notebook for easier way to do this.

# %%
# Sort job_posted_month_name in df_US_pivot by job_posted_month values
df_US_pivot = df_US_pivot.reset_index()
df_US_pivot['job_posted_month_no'] = pd.to_datetime(
    df_US_pivot.job_posted_month, format='%B'
).dt.month

df_US_pivot = df_US_pivot.sort_values('job_posted_month_no')

# set job_posted_month as index (row namea)
df_US_pivot = df_US_pivot.set_index('job_posted_month')

# Drop job_posted_month_no column
df_US_pivot = df_US_pivot.drop(columns='job_posted_month_no')

# Plotting the data
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212

# %% [markdown]
# 5. Let's now graph this.

# %%
df_US_pivot.plot(kind='line', figsize=(12, 6))
plt.title('Job Demand in the US for Data Roles')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.grid()
plt.show()

# %% [markdown]
# Instead we'll just focus on the top 3 roles.

# %%
top_3 = df_US.job_title_short.value_counts().head(3)
top_3 = top_3.index.tolist()
top_3
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
df_US_pivot[top_3].plot(kind='line', figsize=(12, 6))
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Number of Job Postings')
plt.grid()
plt.show()

# %% [markdown]
# Easier Method to Sort Months
#
# After filming the video portion for this I found there is an easier way to sort the months. using the `.to_period('M')` method.

# %%
#  Extract teh month name from 'job_posted_date'
df_US['job_posted_month'] = df_US['job_posted_date'].dt.to_period('M')

# %%
df_US_pivot = df_US.pivot_table(
    index='job_posted_month',
    columns='job_title_short',
    aggfunc='size',
)

df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# 2023-01                        527              36          8494
# 2023-02                        447              24          6124
# 2023-03                        438              19          6218
# 2023-04                        565              40          6049
# 2023-05                        279              20          4993
# 2023-06                        446              32          5683
# 2023-07                        581              39          5201
# 2023-08                        903              39          6634
# 2023-09                        897              50          4639
# 2023-10                        932              48          5271
# 2023-11                        719              36          4531
# 2023-12                        648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# 2023-01                    2655            6915                         60
# 2023-02                    3060            4956                         56
# 2023-03                    3183            4779                         59
# 2023-04                    2801            4867                         51
# 2023-05                    2976            4377                         49
# 2023-06                    2893            4645                         48
# 2023-07                    2570            4876                         65
# 2023-08                    3269            6318                         68
# 2023-09                    3224            4568                        113
# 2023-10                    3015            4882                        101
# 2023-11                    2793            4175                        132
# 2023-12                    2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# 2023-01                          1544                   773
# 2023-02                          1258                   878
# 2023-03                          1114                   829
# 2023-04                          1025                   781
# 2023-05                           839                   746
# 2023-06                          1009                   812
# 2023-07                           883                   747
# 2023-08                          1186                   903
# 2023-09                           805                   775
# 2023-10                           871                   672
# 2023-11                           656                   684
# 2023-12                           601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# 2023-01                            1552                114
# 2023-02                            1127                 90
# 2023-03                            1150                115
# 2023-04                             991                112
# 2023-05                             914                 90
# 2023-06                            1033                 93
# 2023-07                            1095                153
# 2023-08                            1515                194
# 2023-09                            1014                228
# 2023-10                             987                219
# 2023-11                             816                194
# 2023-12                             752                212

# %%
df_US_pivot[top_3].plot(kind='line')
plt.title('Top 3 Job Demand in the US for Data Roles')
plt.xlabel('2023')
plt.ylabel('Number of Job Postings')
plt.show()
